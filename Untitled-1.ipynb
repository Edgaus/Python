# %% [markdown]
# Este documento se estará hablando sobre los ingredientes que nos ofrece Python para poder crear nuestros programas. Tenemos como ingredientes los siguientes:
# Números: Los cuales viene en dos versiones int (Enteros) y float (Flotantes = Racionales en notación decimal)
# Boleanos: Conjunto de dos miembros: True y False, de las pocas palabras que Python ha reservado para su uso explicito. Estos valores nos sirven para construir condicionales y tienen como valor  su signifado.
# Strings: Es un elemento inmutable el cual se denota a partir de " " y por lo general está constituido por secuencias de letras pero tmabin puede incluir números.

# %% [markdown]
# Vaiables: Los objetos en python podemos visualizarlos como cajas en donde dentro hay informacion, ahora la variable es como un sticker pegado a la caja que denota su nombre, por tanto cuando nos referimos auna varable nos estamos refiriendo al nombre de objeto con lo que las variables no tiene en informacion en sí.

# %%
# "a" es el nombre de la varible de un objeto int, que es este caso en 5.
a=5
print(''' El valor de "a" es:''',a)
#Ahora para prrobar que no tiene nada de especial "a", hacemos lo siguiente, definimos "b" como
b=a
print(""" Este es el valor de la variable "b";""",b,'''. Por otro lado este es valor de "a";''',a)
#Podemos darnos cuenta de que tanto "b" como "a" tienen el mismo valor, con nuestra analogia es como si tuvieramos una copia de la caja.
# Out:
#  El valor de "a" es: 5
#  Este es el valor de la variable "b"; 5 . Por otro lado este es valor de "a"; 5

# %% [markdown]
# Algo a rescatar es que para asignar el una variable usamos el signo de "=", esto es debido a que en sus inicios los teclados carecian de signos de relacion matematicas como flechas, además la conotacion de "=" en matemtcias, de dos objetos que sean iguales, es mucho menos usado que el de asignacion que casí en todos los progrmas que escribiras usaras esta estructura por lo que no hay mucho incoveniente.

# %% [markdown]
# Otra cosa a considerar es el como se
